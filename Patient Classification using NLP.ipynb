# %%
import os
import numpy as np
import pandas as pd
import time
import math
from sklearn.model_selection import train_test_split
from sklearn import metrics
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, CuDNNGRU, Conv1D
from keras.layers import Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer 
from nltk.stem.snowball import SnowballStemmer
from urllib.parse import urlparse 
from keras.models import Sequential

# %%
data = pd.read_csv("../input/train.csv", encoding = "ISO-8859-1")
df2 = data.assign(Data = data.Title.astype(str) + ' ' + data.TRANS_CONV_TEXT.astype(str) + ' ' + data.Source.astype(str))
df2 = df2.drop(df2.columns[[1,2,3,4,5,6]], axis = 1)

# %%
df2.head()
# Out:
#    Source                        ...                                                                       Data
# 0  FORUMS                        ...                          Epstein I don't disagree with you in principle...
# 1  FORUMS                        ...                          Enlarged Heart.Thread Enlarged Heart I am alwa...
# 2    BLOG                        ...                          Queen Latifah Joins American Heart Association...
# 3  FORUMS                        ...                          Bulaemia I am 17 and I have been throwing up f...
# 4  FORUMS                        ...                          DIY Silver interconnects and RCAs??? Quote: Or...
#
# [5 rows x 3 columns]

# %%
def remove_punctuation(text):
    import string
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)
def remove_url(data):
    if data.startswith('www.'):
        data = re.sub(r'www.', '', data)
    if data.startswith('http.'):
        data = re.sub(r'http.', '', data)
    domain = data.split("//")[-1].split("/")[0]
    return domain

# %%
# df2['Data'] = df2['Data'].apply(remove_url)
df2['Data'] = df2['Data'].apply(remove_punctuation)

# %%
df2.head()
# Out:
#    Source                        ...                                                                       Data
# 0  FORUMS                        ...                          Epstein I dont disagree with you in principle ...
# 1  FORUMS                        ...                          Enlarged HeartThread Enlarged Heart I am alway...
# 2    BLOG                        ...                          Queen Latifah Joins American Heart Association...
# 3  FORUMS                        ...                          Bulaemia I am 17 and I have been throwing up f...
# 4  FORUMS                        ...                          DIY Silver interconnects and RCAs Quote Origin...
#
# [5 rows x 3 columns]

# %%
df2 = df2.drop(df2.columns[[0]], axis = 1)

sw = stopwords.words('english')
print(sw)

def stopwords(text):
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    return " ".join(text)
df2['Data'] = df2['Data'].apply(stopwords)
df2.head()
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
#    Patient_Tag                                               Data
# 0            0  epstein dont disagree principle im saying entr...
# 1            1  enlarged heartthread enlarged heart always diz...
# 2            0  queen latifah joins american heart association...
# 3            1  bulaemia 17 throwing year nowalmost everyday t...
# 4            0  diy silver interconnects rcas quote originally...

# %%
stemmer = SnowballStemmer("english")

def stemming(text):    
    text = [stemmer.stem(word) for word in text.split()]
    return " ".join(text) 
y = df2['Patient_Tag']
df2['Data'] = df2['Data'].apply(stemming)

# %%
df2.head()
# Out:
#    Patient_Tag                                               Data
# 0            0  epstein dont disagre principl im say entresto ...
# 1            1  enlarg heartthread enlarg heart alway dizzi ge...
# 2            0  queen latifah join american heart associ red s...
# 3            1  bulaemia 17 throw year nowalmost everyday thro...
# 4            0  diy silver interconnect rcas quot origin post ...

# %%
train_data, val_data = train_test_split(df2, test_size = 0.1, random_state = 2020)

#Text preprocessing
train_y = train_data['Patient_Tag'].values
val_y = val_data['Patient_Tag'].values
train_data = train_data.drop('Patient_Tag', axis = 1)
val_data = val_data.drop('Patient_Tag', axis = 1)
train_x = train_data["Data"].fillna("_na_").values
val_x = val_data["Data"].fillna("_na_").values


embed_size = 500
max_features = 95000
max_len = 1200

# %%
length = []
for x in train_data["Data"]:
    length.append(len(x.split()))
print("Maximum length of question text is: ",max(length))
# Out:
# Maximum length of question text is:  1561

# %%
tokenizer = Tokenizer(num_words = max_features, filters = '!"#$%&()*+,-./:;<=>?@[\]^_`{|}~...=', lower=True) #Taken care of filters and lower case
tokenizer.fit_on_texts(train_x)
print(tokenizer.word_counts)
# Out:
# OrderedDict([('stem', 113), ('cell', 324), ('therapi', 246), ('halv', 9), ('death', 345), ('heart', 2732), ('failur', 1240), ('im', 188), ('begin', 58), ('suspect', 25), ('even', 311), ('adult', 121), ('ive', 101), ('got', 81), ('read', 175), ('articl', 108), ('line', 69), ('appear', 90), ('add', 44), ('5', 141), ('year', 543), ('someon', 75), ('life', 271), ('see', 247), ('make', 330), ('big', 60), ('diff', 3), ('long', 145), ('run', 55), ('put', 111), ('inevit', 6), ('cure', 29), ('delay', 22), ('bit', 40), ('wont', 31), ('complain', 15), ('situationmayb', 2), ('could', 318), ('actual', 112), ('come', 156), ('someth', 106), ('work', 283), ('unlik', 22), ('forum', 507), ('nebraska', 1), ('beyond', 23), ('sunday', 47), ('58', 5), ('happi', 50), ('mother', 78), ('day', 358), ('enjoy', 34), ('sure', 76), ('nasti', 3), ('outsid', 23), ('today', 138), ('friend', 79), ('karen', 3), ('hard', 55), ('time', 535), ('breath', 156), ('warn', 41), ('go', 320), ('asthma', 37), ('get', 475), ('congest', 193), ('dont', 203), ('need', 377), ('ad', 88), ('smoke', 43), ('realli', 125), ('hope', 129), ('canada', 26), ('fire', 19), ('soon', 55), ('plan', 98), ('either', 58), ('breakfast', 18), ('lunch', 5), ('sinc', 135), ('cant', 64), ('ill', 141), ('pancak', 1), ('home', 166), ('take', 380), ('care', 313), ('pasta', 3), ('salad', 3), ('four', 56), ('way', 215), ('poor', 42), ('enlarg', 51), ('fact', 85), ('obstruct', 61), ('sleep', 232), ('apnea', 116), ('richardson', 5), ('tx', 7), ('resid', 27), ('know', 298), ('john', 35), ('young', 62), ('disord', 139), ('character', 22), ('intermitt', 2), ('interrupt', 9), ('affect', 109), ('individu', 83), ('wake', 29), ('everi', 152), ('often', 144), ('person', 206), ('problem', 311), ('tend', 33), ('snore', 25), ('excess', 66), ('tire', 23), ('drowsi', 5), ('due', 157), ('lack', 51), ('good', 212), ('qualiti', 92), ('number', 151), ('understand', 70), ('struggl', 23), ('under', 48), ('condit', 319), ('relax', 43), ('throat', 15), ('muscl', 167), ('compris', 9), ('soft', 14), ('palat', 2), ('tonsil', 5), ('uvula', 2), ('narrow', 15), ('space', 30), ('use', 658), ('inhal', 7), ('air', 52), ('total', 118), ('occur', 96), ('period', 80), ('ten', 16), ('twenti', 6), ('second', 77), ('caus', 555), ('arous', 1), ('result', 337), ('vibrat', 2), ('loos', 7), ('forc', 60), ('factor', 146), ('shown', 69), ('predispos', 5), ('weight', 163), ('one', 545), ('risk', 609), ('present', 129), ('50', 67), ('believ', 103), ('contribut', 61), ('increas', 424), ('fat', 136), ('deposit', 16), ('around', 152), ('upper', 18), ('airway', 22), ('subsequ', 13), ('lead', 256), ('relat', 161), ('possess', 9), ('larg', 106), ('neck', 22), ('defin', 35), ('circumfer', 6), ('16', 36), ('inch', 7), ('women', 118), ('17', 35), ('men', 90), ('other', 86), ('chronic', 169), ('nasal', 5), ('hypertens', 184), ('diabet', 268), ('treat', 242), ('may', 569), ('complic', 79), ('cardiovascular', 282), ('reduc', 261), ('oxygen', 49), ('blood', 873), ('turn', 82), ('strain', 17), ('abnorm', 46), ('rhythm', 48), ('arrhythmia', 43), ('anoth', 131), ('major', 105), ('product', 243), ('daytim', 6), ('fatigu', 49), ('children', 98), ('poorer', 3), ('academ', 8), ('perform', 114), ('compar', 162), ('peer', 10), ('first', 381), ('step', 46), ('deal', 41), ('institut', 75), ('lifestyl', 71), ('chang', 178), ('lose', 64), ('classifi', 9), ('overweight', 34), ('obes', 80), ('measur', 96), ('undertaken', 1), ('easili', 19), ('includ', 462), ('part', 151), ('regular', 69), ('physic', 88), ('exercis', 113), ('alcohol', 110), ('intak', 73), ('case', 252), ('steroid', 12), ('base', 125), ('decongest', 1), ('offer', 110), ('benefit', 180), ('treatment', 468), ('option', 87), ('consid', 89), ('prove', 19), ('ineffect', 5), ('devic', 164), ('open', 74), ('block', 61), ('sever', 242), ('dental', 5), ('specialist', 35), ('appropri', 27), ('surgeri', 139), ('last', 193), ('resort', 5), ('type', 185), ('oper', 90), ('depend', 53), ('common', 182), ('procedur', 113), ('r ...

# %%
train_x = tokenizer.texts_to_sequences(train_x)
val_x = tokenizer.texts_to_sequences(val_x)
train_x = pad_sequences(train_x, maxlen = max_len)
val_x = pad_sequences(val_x, maxlen = max_len)

# %%
mod = Sequential()
mod.add(layers.Embedding((max_features), embed_size))
mod.add(layers.Bidirectional(CuDNNGRU(64,return_sequences = True)))
mod.add(layers.Dense(64, activation='relu'))
mod.add(layers.GlobalMaxPool1D())
mod.add(layers.Dense(16, activation='relu'))
mod.add(layers.Dropout(0.1))
mod.add(layers.Dense(1, activation='sigmoid'))
mod.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
mod.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 500)         47500000
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, None, 128)         217344
# _________________________________________________________________
# dense_4 (Dense)              (None, None, 64)          8256
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 47,726,657
# Trainable params: 47,726,657
# Non-trainable params: 0
# _________________________________________________________________

# %%
mod.fit(train_x, train_y, batch_size = 512, epochs = 20, validation_data = (val_x, val_y))
# Out:
# Train on 833 samples, validate on 93 samples
# Epoch 1/20
# 833/833 [==============================] - 5s 6ms/step - loss: 0.6844 - acc: 0.5438 - val_loss: 0.6209 - val_acc: 0.9032
# Epoch 2/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.6096 - acc: 0.8583 - val_loss: 0.5183 - val_acc: 0.9032
# Epoch 3/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.5180 - acc: 0.8607 - val_loss: 0.4179 - val_acc: 0.9032
# Epoch 4/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.4335 - acc: 0.8607 - val_loss: 0.3458 - val_acc: 0.9032
# Epoch 5/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.3877 - acc: 0.8607 - val_loss: 0.3100 - val_acc: 0.9032
# Epoch 6/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.3887 - acc: 0.8607 - val_loss: 0.3025 - val_acc: 0.9032
# Epoch 7/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.3904 - acc: 0.8607 - val_loss: 0.2982 - val_acc: 0.9032
# Epoch 8/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.3727 - acc: 0.8607 - val_loss: 0.2913 - val_acc: 0.9032
# Epoch 9/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.3623 - acc: 0.8607 - val_loss: 0.2850 - val_acc: 0.9032
# Epoch 10/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.3399 - acc: 0.8607 - val_loss: 0.2828 - val_acc: 0.9032
# Epoch 11/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.3131 - acc: 0.8607 - val_loss: 0.2831 - val_acc: 0.9032
# Epoch 12/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.3079 - acc: 0.8607 - val_loss: 0.2826 - val_acc: 0.9032
# Epoch 13/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.2862 - acc: 0.8619 - val_loss: 0.2781 - val_acc: 0.9032
# Epoch 14/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.2667 - acc: 0.8643 - val_loss: 0.2687 - val_acc: 0.9140
# Epoch 15/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.2514 - acc: 0.8739 - val_loss: 0.2557 - val_acc: 0.9140
# Epoch 16/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.2205 - acc: 0.8944 - val_loss: 0.2402 - val_acc: 0.9140
# Epoch 17/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.1975 - acc: 0.9160 - val_loss: 0.2242 - val_acc: 0.9140
# Epoch 18/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.1712 - acc: 0.9364 - val_loss: 0.2098 - val_acc: 0.9247
# Epoch 19/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.1451 - acc: 0.9664 - val_loss: 0.1973 - val_acc: 0.9355
# Epoch 20/20
# 833/833 [==============================] - 2s 3ms/step - loss: 0.1230 - acc: 0.9760 - val_loss: 0.1870 - val_acc: 0.9355
